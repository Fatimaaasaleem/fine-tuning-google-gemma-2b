# %%
# !pip uninstall -y transformers trl peft accelerate bitsandbytes sentence-transformers

# !pip install -q \
transformers \
trl \
peft \
accelerate \
bitsandbytes
# Out:
# Found existing installation: transformers 5.7.0
# Uninstalling transformers-5.7.0:
#   Successfully uninstalled transformers-5.7.0
# Found existing installation: trl 1.3.0
# Uninstalling trl-1.3.0:
#   Successfully uninstalled trl-1.3.0
# Found existing installation: peft 0.19.1
# Uninstalling peft-0.19.1:
#   Successfully uninstalled peft-0.19.1
# Found existing installation: accelerate 1.13.0
# Uninstalling accelerate-1.13.0:
#   Successfully uninstalled accelerate-1.13.0
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: bitsandbytes 0.49.2
# Uninstalling bitsandbytes-0.49.2:
#   Successfully uninstalled bitsandbytes-0.49.2
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# WARNING: Skipping sentence-transformers as it is not installed.
# WARNING: Ignoring invalid distribution ~yarrow (/usr/local/lib/python3.12/dist-packages)
# ...

# %%
import os
import torch
import transformers

from datasets import load_dataset
from trl import SFTTrainer
from peft import LoraConfig

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    GemmaTokenizer
)

from google.colab import userdata

# %%
os.environ['HF_TOKEN']=userdata.get('HF_TOKEN')

# %%
#prerequisites
model_id='google/gemma-2b'
#trying to convert the gemma model that we are using from 32 bits to 4 bits
bnb_config=BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_compute_dtype=torch.bfloat16
)
#all the weights will be converted to 4bit
#using 4 bit quantization
#compute dtype was kept 16bit, to balance the loss of info happened due to quantizarion

# %%
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
import os

tokenizer = AutoTokenizer.from_pretrained(
    "google/gemma-2b"
)

model = AutoModelForCausalLM.from_pretrained(
    "google/gemma-2b",
    quantization_config=bnb_config,
    device_map="auto",

)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     760     try:
# --> 761         response.raise_for_status()
#     762     except httpx.HTTPStatusError as e:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_models.py in raise_for_status(self)
#     828         message = message.format(self, error_type=error_type)
# --> 829         raise HTTPStatusError(message, request=request, response=self)
#     830
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://huggingface.co/google/gemma-2b/resolve/main/config.json'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
text="Quote: Imagination is more,"
device='cuda:0'
inputs=tokenizer(text,return_tensors='pt').to(device)

outputs=model.generate(**inputs,max_new_tokens=50)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
#   File "/tmp/ipykernel_771/2770443926.py", line 6
#     print(tokenizer.decode(outputs[0],skip_special_tokens=True)
#                                                                ^
# SyntaxError: incomplete input

# %%
 os.environ['WANDB_DISABLED']='false'

# %%
lora_config=LoraConfig(
    r=8;
    target_modules=["q_proj","o_proj","k_proj","v_proj",
                    "gate_proj","up_proj","down_proj"],
    task_type="CASUAL_LM"
)

# %%
from datasets import load_dataset
data=load_dataset("Abirate/english_quotes")
data=data.map(lambda samples:tokenizer(samples['quote']),batched=True)

# %%
 data['train']['quote']

# %%
def formatting_func(example):
  text=f'Quote:{example["quote"][0]}\n Author:{example['author'][0]}'
  return [text]

# %%
trainer=SFTTrainer(
    model=model,
    train_dataset=data['train'],
    args=trasnformers.TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=4,
        warmup_steps=2,
        max_steps=100,
        learning_rate=2e-4,
        fp16=True,
        logging_steps=1,
        output_dir='outputs',
        optim="paged_adamw_8bit"
    ),
    peft_config=lora_config,
    formatting_func=formatting_func,
)

# %%
trainer.train()

# %%
text="Quote:A woman is like a tea bag"
device='cuda:0'
inputs=tokenizer(text,return_tensors='pt').to(device)

outputs=model.generate(**inputs,max_tokens=20)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
